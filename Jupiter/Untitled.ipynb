# %%
gg = 'iwas_Seed234_volumeFaction2'

# %%
st = gg.split('_')
st
# Out:
# ['iwas', 'Seed234', 'volumeFaction2']

# %%
st = [''.join([z for z in kk if not z.isdigit()]) for kk in st]

# %%
st
# Out:
# ['iwas', 'Seed', 'volumeFaction']

# %%
gg = []
kk = [1,2,3,4]
gg.extend(kk)
print(gg)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]
